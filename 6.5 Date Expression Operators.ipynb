# %% [markdown]
# # Date Expression Operators

# %% [markdown]
# ---
# ### Connecting to MongoDB using Pymongo
# ----

# %%
# Importing the required libraries
import pymongo
import pprint as pp

pp.sorted = lambda x, key=None: x

# %%
# Connect to the mongo client - Atlas Cluster
client = pymongo.MongoClient('mongodb://localhost:27017/')

# %%
# training dataset
db = client.training

# %%
# Sample hr document
pp.pprint(
    db.hr.find_one()
)
# Out:
# {'_id': ObjectId('63ce280590fbea39fda03282'),
#  'indexes': [{'v': 2, 'key': {'_id': 1}, 'name': '_id_'}],
#  'uuid': 'cf2a3af8d73c4679bb0e7392895881b9',
#  'collectionName': 'hr'}

# %% [markdown]
# ---
# ---
# ### [Date Expression Operators](https://docs.mongodb.com/manual/reference/operator/aggregation/#date-expression-operators)
#
# Return date objects or components of a date object.
#
# ----
#
# For example, we can return day of month, month, year, etc. from operators like  [\$dayOfMonth](https://docs.mongodb.com/manual/reference/operator/aggregation/dayOfMonth/#mongodb-expression-exp.-dayOfMonth), [\$month](https://docs.mongodb.com/manual/reference/operator/aggregation/month/#mongodb-expression-exp.-month), [\$year](https://docs.mongodb.com/manual/reference/operator/aggregation/year/#mongodb-expression-exp.-year).
#
# ---

# %%
# Date expression operators

result = db.hr.aggregate(
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                            '_id':0,
                            'Original_date':'$date_of_enrollment',
                            # day of month
                            'Day_of_Month':{'$dayOfMonth':'$date_of_enrollment'},
                            # day of year
                            'Day_of_year':{'$dayOfYear':'$date_of_enrollment'},
                            # day of week
                            'Day_of_Week':{'$isoDayOfWeek':'$date_of_enrollment'},
                            # week of year
                            'Week_of_Year':{'$isoWeek':'$date_of_enrollment'},
                            # month
                            'Month':{'$month':'$date_of_enrollment'},
                            # year
                            'Year':{'$year':'$date_of_enrollment'},
                            # hour
                            'Hour':{'$hour':'$date_of_enrollment'},
                            # minute
                            'Minute':{'$minute':'$date_of_enrollment'},
                            # second
                            'Second':{'$second':'$date_of_enrollment'},
                            # Millisecond
                            'Millisecond':{'$millisecond':'$date_of_enrollment'}
                            }
            },
            
            # Stage 3
            {
                '$limit':1
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'Original_date': datetime.datetime(2016, 1, 23, 0, 0),
#  'Day_of_Month': 23,
#  'Day_of_year': 23,
#  'Day_of_Week': 6,
#  'Week_of_Year': 3,
#  'Month': 1,
#  'Year': 2016,
#  'Hour': 0,
#  'Minute': 0,
#  'Second': 0,
#  'Millisecond': 0}

# %% [markdown]
# ---
# **These returned dat objects can then be used in subsequent stages.**
#
# ----

# %%
# Date expression operators

result = db.hr.aggregate(
        # Pipeline
        [
            # Stage 1
            {
                '$match':{'education.discipline':'STEM'}
            },
            
            # Stage 2
            {
                '$project':{
                            '_id':0,
                            'Original_date':'$date_of_enrollment',
                            'Day':{'$dayOfMonth':'$date_of_enrollment'},
                            'Month':{'$month':'$date_of_enrollment'},
                            'Year':{'$year':'$date_of_enrollment'},
                            }
            },
            
            # Stage 3
            {
                '$match': {
                            'Month':{'$gt':6},
                            'Year':{'$gt':2018}
                        }
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'Original_date': datetime.datetime(2020, 11, 24, 0, 0),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 19, 0, 0),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 24, 0, 0),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 8, 0, 0),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 3, 0, 0),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 20, 0, 0),
#  'Day': 20,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 7, 0, 0),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 11, 0, 0),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 20, 0, 0),
#  'Day': 20,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 0, 0),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 25, 0, 0),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 22, 0, 0),
#  'Day': 22,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 14, 0, 0),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 2, 0, 0),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 22, 0, 0),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 8, 0, 0),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 17, 0, 0),
#  'Day': 17,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 20, 0, 0),
#  'Day': 20,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 29, 0, 0),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 20, 0, 0),
#  'Day': 20,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 29, 0, 0),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 15, 0, 0),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 25, 0, 0),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 8, 0, 0),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 15, 0, 0),
#  'Day': 15,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 16, 0, 0),
#  'Day': 16,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 26, 0, 0),
#  'Day': 26,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 30, 0, 0),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 16, 0, 0),
#  'Day': 16,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 7, 0, 0),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 5, 0, 0),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 29, 0, 0),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 9, 0, 0),
#  'Day': 9,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 14, 0, 0),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 12, 0, 0),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 13, 0, 0),
#  'Day': 13,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 2, 0, 0),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 23, 0, 0),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 8, 0, 0),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 20, 0, 0),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 30, 0, 0),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 12, 0, 0),
#  'Day': 12,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 15, 0, 0),
#  'Day': 15,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 11, 0, 0),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 10, 0, 0),
#  'Day': 10,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 14, 0, 0),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 3, 0, 0),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 7, 0, 0),
#  'Day': 7,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 11, 0, 0),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 22, 0, 0),
#  'Day': 22,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 17, 0, 0),
#  'Day': 17,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 11, 0, 0),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 12, 0, 0),
#  'Day': 12,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 15, 0, 0),
#  'Day': 15,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 18, 0, 0),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 27, 0, 0),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 1, 0, 0),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 30, 0, 0),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 31, 0, 0),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 12, 0, 0),
#  'Day': 12,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 22, 0, 0),
#  'Day': 22,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 20, 0, 0),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 24, 0, 0),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 8, 0, 0),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 26, 0, 0),
#  'Day': 26,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 2, 0, 0),
#  'Day': 2,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 5, 0, 0),
#  'Day': 5,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 13, 0, 0),
#  'Day': 13,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 29, 0, 0),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 16, 0, 0),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 2, 0, 0),
#  'Day': 2,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 4, 0, 0),
#  'Day': 4,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 8, 0, 0),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 18, 0, 0),
#  'Day': 18,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 15, 0, 0),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 1, 0, 0),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 29, 0, 0),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 20, 0, 0),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 17, 0, 0),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 16, 0, 0),
#  'Day': 16,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 4, 0, 0),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 6, 0, 0),
#  'Day': 6,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 28, 0, 0),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 18, 0, 0),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 5, 0, 0),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 10, 0, 0),
#  'Day': 10,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 23, 0, 0),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 25, 0, 0),
#  'Day': 25,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 11, 0, 0),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 24, 0, 0),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 4, 0, 0),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 12, 0, 0),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 5, 0, 0),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 4, 0, 0),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 21, 0, 0),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 19, 0, 0),
#  'Day': 19,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 1, 0, 0),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 4, 0, 0),
#  'Day': 4,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 12, 0, 0),
#  'Day': 12,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 28, 0, 0),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 9, 0, 0),
#  'Day': 9,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 17, 0, 0),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 24, 0, 0),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 17, 0, 0),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 15, 0, 0),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 23, 0, 0),
#  'Day': 23,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 22, 0, 0),
#  'Day': 22,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 18, 0, 0),
#  'Day': 18,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 29, 0, 0),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 7, 0, 0),
#  'Day': 7,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 25, 0, 0),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 4, 0, 0),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 7, 0, 0),
#  'Day': 7,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 24, 0, 0),
#  'Day': 24,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 18, 0, 0),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 2, 0, 0),
#  'Day': 2,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 28, 0, 0),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 29, 0, 0),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 11, 0, 0),
#  'Day': 11,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 7, 0, 0),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 2, 0, 0),
#  'Day': 2,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 29, 0, 0),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 28, 0, 0),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 17, 0, 0),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 17, 0, 0),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 6, 0, 0),
#  'Day': 6,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 24, 0, 0),
#  'Day': 24,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 18, 0, 0),
#  'Day': 18,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 24, 0, 0),
#  'Day': 24,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 10, 0, 0),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 28, 0, 0),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 8, 0, 0),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 24, 0, 0),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 21, 0, 0),
#  'Day': 21,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 23, 0, 0),
#  'Day': 23,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 10, 0, 0),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 8, 0, 0),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 11, 0, 0),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 3, 0, 0),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 21, 0, 0),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 24, 0, 0),
#  'Day': 24,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 8, 0, 0),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 4, 0, 0),
#  'Day': 4,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 17, 0, 0),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 12, 0, 0),
#  'Day': 12,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 28, 0, 0),
#  'Day': 28,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 15, 0, 0),
#  'Day': 15,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 11, 0, 0),
#  'Day': 11,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 15, 0, 0),
#  'Day': 15,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 25, 0, 0),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 5, 0, 0),
#  'Day': 5,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 18, 0, 0),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 8, 0, 0),
#  'Day': 8,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 24, 0, 0),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 27, 0, 0),
#  'Day': 27,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 31, 0, 0),
#  'Day': 31,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 25, 0, 0),
#  'Day': 25,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 7, 0, 0),
#  'Day': 7,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 27, 0, 0),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 13, 0, 0),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 22, 0, 0),
#  'Day': 22,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 14, 0, 0),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 20, 0, 0),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 21, 0, 0),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 11, 0, 0),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 4, 0, 0),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 10, 0, 0),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 9, 0, 0),
#  'Day': 9,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 4, 0, 0),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 30, 0, 0),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 10, 0, 0),
#  'Day': 10,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 7, 0, 0),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 8, 0, 0),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 20, 0, 0),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 15, 0, 0),
#  'Day': 15,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 20, 0, 0),
#  'Day': 20,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 27, 0, 0),
#  'Day': 27,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 23, 0, 0),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 28, 0, 0),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 18, 0, 0),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 16, 0, 0),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 17, 0, 0),
#  'Day': 17,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 9, 0, 0),
#  'Day': 9,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 7, 0, 0),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 12, 0, 0),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 15, 0, 0),
#  'Day': 15,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 1, 0, 0),
#  'Day': 1,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 25, 0, 0),
#  'Day': 25,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 14, 0, 0),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 16, 0, 0),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 13, 0, 0),
#  'Day': 13,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 8, 0, 0),
#  'Day': 8,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 3, 0, 0),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 18, 0, 0),
#  'Day': 18,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 17, 0, 0),
#  'Day': 17,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 3, 0, 0),
#  'Day': 3,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 7, 0, 0),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 18, 0, 0),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 16, 0, 0),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 17, 0, 0),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 25, 0, 0),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 13, 0, 0),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 21, 0, 0),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 9, 0, 0),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 30, 0, 0),
#  'Day': 30,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 18, 0, 0),
#  'Day': 18,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 17, 0, 0),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 18, 0, 0),
#  'Day': 18,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 25, 0, 0),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 20, 0, 0),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 10, 0, 0),
#  'Day': 10,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 28, 0, 0),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 30, 0, 0),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 2, 0, 0),
#  'Day': 2,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 27, 0, 0),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 22, 0, 0),
#  'Day': 22,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 19, 0, 0),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 25, 0, 0),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 28, 0, 0),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 4, 0, 0),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 5, 0, 0),
#  'Day': 5,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 3, 0, 0),
#  'Day': 3,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 4, 0, 0),
#  'Day': 4,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 29, 0, 0),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 10, 0, 0),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 6, 0, 0),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 17, 0, 0),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 25, 0, 0),
#  'Day': 25,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 25, 0, 0),
#  'Day': 25,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 24, 0, 0),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 13, 0, 0),
#  'Day': 13,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 20, 0, 0),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 30, 0, 0),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 28, 0, 0),
#  'Day': 28,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 4, 0, 0),
#  'Day': 4,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 4, 0, 0),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 22, 0, 0),
#  'Day': 22,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 21, 0, 0),
#  'Day': 21,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 12, 0, 0),
#  'Day': 12,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 14, 0, 0),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 22, 0, 0),
#  'Day': 22,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 23, 0, 0),
#  'Day': 23,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 4, 0, 0),
#  'Day': 4,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 26, 0, 0),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 26, 0, 0),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 28, 0, 0),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 1, 0, 0),
#  'Day': 1,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 28, 0, 0),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 8, 0, 0),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 25, 0, 0),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 4, 0, 0),
#  'Day': 4,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 11, 0, 0),
#  'Day': 11,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 17, 0, 0),
#  'Day': 17,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 1, 0, 0),
#  'Day': 1,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 6, 0, 0),
#  'Day': 6,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 2, 0, 0),
#  'Day': 2,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 1, 0, 0),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 29, 0, 0),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 16, 0, 0),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 3, 0, 0),
#  'Day': 3,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 8, 0, 0),
#  'Day': 8,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 27, 0, 0),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 11, 0, 0),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 6, 0, 0),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 9, 0, 0),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 26, 0, 0),
#  'Day': 26,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 6, 0, 0),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 29, 0, 0),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 6, 0, 0),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 3, 0, 0),
#  'Day': 3,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 17, 0, 0),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 24, 0, 0),
#  'Day': 24,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 4, 0, 0),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 26, 0, 0),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 22, 0, 0),
#  'Day': 22,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 7, 0, 0),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 20, 0, 0),
#  'Day': 20,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 17, 0, 0),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 9, 0, 0),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 30, 0, 0),
#  'Day': 30,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 14, 0, 0),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 1, 0, 0),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 6, 0, 0),
#  'Day': 6,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 21, 0, 0),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 2, 0, 0),
#  'Day': 2,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 27, 0, 0),
#  'Day': 27,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 14, 0, 0),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 26, 0, 0),
#  'Day': 26,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 7, 0, 0),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 4, 0, 0),
#  'Day': 4,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 11, 0, 0),
#  'Day': 11,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 5, 0, 0),
#  'Day': 5,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 30, 0, 0),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 11, 0, 0),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 13, 0, 0),
#  'Day': 13,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 24, 0, 0),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 15, 0, 0),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 7, 0, 0),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 18, 0, 0),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 20, 0, 0),
#  'Day': 20,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 21, 0, 0),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 29, 0, 0),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 19, 0, 0),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 7, 0, 0),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 14, 0, 0),
#  'Day': 14,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 26, 0, 0),
#  'Day': 26,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 24, 0, 0),
#  'Day': 24,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 24, 0, 0),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 12, 0, 0),
#  'Day': 12,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 18, 0, 0),
#  'Day': 18,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 1, 0, 0),
#  'Day': 1,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 8, 0, 0),
#  'Day': 8,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 2, 0, 0),
#  'Day': 2,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 15, 0, 0),
#  'Day': 15,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 25, 0, 0),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 26, 0, 0),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 14, 0, 0),
#  'Day': 14,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 22, 0, 0),
#  'Day': 22,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 2, 0, 0),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 9, 0, 0),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 14, 0, 0),
#  'Day': 14,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 7, 0, 0),
#  'Day': 7,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 11, 0, 0),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 11, 0, 0),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 7, 0, 0),
#  'Day': 7,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 8, 0, 0),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 24, 0, 0),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 24, 0, 0),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 10, 0, 0),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 10, 0, 0),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 2, 0, 0),
#  'Day': 2,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 9, 0, 0),
#  'Day': 9,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 22, 0, 0),
#  'Day': 22,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 16, 0, 0),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 3, 0, 0),
#  'Day': 3,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 2, 0, 0),
#  'Day': 2,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 3, 0, 0),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 5, 0, 0),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 16, 0, 0),
#  'Day': 16,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 18, 0, 0),
#  'Day': 18,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 23, 0, 0),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 21, 0, 0),
#  'Day': 21,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 5, 0, 0),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 8, 0, 0),
#  'Day': 8,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 14, 0, 0),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 23, 0, 0),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 9, 0, 0),
#  'Day': 9,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 30, 0, 0),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 15, 0, 0),
#  'Day': 15,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 7, 0, 0),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 17, 0, 0),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 26, 0, 0),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 6, 0, 0),
#  'Day': 6,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 1, 0, 0),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 11, 0, 0),
#  'Day': 11,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 31, 0, 0),
#  'Day': 31,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 19, 0, 0),
#  'Day': 19,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 27, 0, 0),
#  'Day': 27,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 24, 0, 0),
#  'Day': 24,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 12, 0, 0),
#  'Day': 12,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 30, 0, 0),
#  'Day': 30,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 21, 0, 0),
#  'Day': 21,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 4, 0, 0),
#  'Day': 4,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 15, 0, 0),
#  'Day': 15,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 23, 0, 0),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 14, 0, 0),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 3, 0, 0),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 31, 0, 0),
#  'Day': 31,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 23, 0, 0),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 11, 0, 0),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 17, 0, 0),
#  'Day': 17,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 21, 0, 0),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 7, 0, 0),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 7, 0, 0),
#  'Day': 7,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 13, 0, 0),
#  'Day': 13,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 26, 0, 0),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 12, 0, 0),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 3, 0, 0),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 10, 0, 0),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 9, 0, 0),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 25, 0, 0),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 4, 0, 0),
#  'Day': 4,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 19, 0, 0),
#  'Day': 19,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 1, 0, 0),
#  'Day': 1,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 5, 0, 0),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 9, 0, 0),
#  'Day': 9,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 0, 0),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 28, 0, 0),
#  'Day': 28,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 14, 0, 0),
#  'Day': 14,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 24, 0, 0),
#  'Day': 24,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 7, 0, 0),
#  'Day': 7,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 30, 0, 0),
#  'Day': 30,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 15, 0, 0),
#  'Day': 15,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 23, 0, 0),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 3, 0, 0),
#  'Day': 3,
#  'Month': 12,
#  'Year': 2019}
# ...
# {'Original_date': datetime.datetime(2019, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 27, 0, 0),
#  'Day': 27,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 9, 0, 0),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 13, 0, 0),
#  'Day': 13,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 26, 0, 0),
#  'Day': 26,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 27, 0, 0),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 3, 0, 0),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 18, 0, 0),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 22, 0, 0),
#  'Day': 22,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 23, 0, 0),
#  'Day': 23,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 3, 0, 0),
#  'Day': 3,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 14, 0, 0),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 2, 0, 0),
#  'Day': 2,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 18, 0, 0),
#  'Day': 18,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 1, 0, 0),
#  'Day': 1,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 21, 0, 0),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 10, 0, 0),
#  'Day': 10,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 17, 0, 0),
#  'Day': 17,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 29, 0, 0),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 13, 0, 0),
#  'Day': 13,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 9, 0, 0),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 17, 0, 0),
#  'Day': 17,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 6, 0, 0),
#  'Day': 6,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 16, 0, 0),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 8, 0, 0),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 3, 0, 0),
#  'Day': 3,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 20, 0, 0),
#  'Day': 20,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 27, 0, 0),
#  'Day': 27,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 31, 0, 0),
#  'Day': 31,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 8, 0, 0),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 21, 0, 0),
#  'Day': 21,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 10, 0, 0),
#  'Day': 10,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 29, 0, 0),
#  'Day': 29,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 24, 0, 0),
#  'Day': 24,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 20, 0, 0),
#  'Day': 20,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 28, 0, 0),
#  'Day': 28,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 4, 0, 0),
#  'Day': 4,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 19, 0, 0),
#  'Day': 19,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 7, 0, 0),
#  'Day': 7,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 11, 0, 0),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 18, 0, 0),
#  'Day': 18,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 11, 0, 0),
#  'Day': 11,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 29, 0, 0),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 17, 0, 0),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 31, 0, 0),
#  'Day': 31,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 1, 0, 0),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 17, 0, 0),
#  'Day': 17,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 8, 0, 0),
#  'Day': 8,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 29, 0, 0),
#  'Day': 29,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 1, 0, 0),
#  'Day': 1,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 28, 0, 0),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 24, 0, 0),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 2, 0, 0),
#  'Day': 2,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 13, 0, 0),
#  'Day': 13,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 17, 0, 0),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 3, 0, 0),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 29, 0, 0),
#  'Day': 29,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 12, 0, 0),
#  'Day': 12,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 20, 0, 0),
#  'Day': 20,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 14, 0, 0),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 25, 0, 0),
#  'Day': 25,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 2, 0, 0),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 7, 0, 0),
#  'Day': 7,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 30, 0, 0),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 7, 24, 0, 0),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 16, 0, 0),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 3, 0, 0),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 16, 0, 0),
#  'Day': 16,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 4, 0, 0),
#  'Day': 4,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 14, 0, 0),
#  'Day': 14,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 11, 0, 0),
#  'Day': 11,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 30, 0, 0),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 4, 0, 0),
#  'Day': 4,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 27, 0, 0),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 30, 0, 0),
#  'Day': 30,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 29, 0, 0),
#  'Day': 29,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 21, 0, 0),
#  'Day': 21,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 23, 0, 0),
#  'Day': 23,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 4, 0, 0),
#  'Day': 4,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 17, 0, 0),
#  'Day': 17,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 24, 0, 0),
#  'Day': 24,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 2, 0, 0),
#  'Day': 2,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 24, 0, 0),
#  'Day': 24,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 3, 0, 0),
#  'Day': 3,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 27, 0, 0),
#  'Day': 27,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 6, 0, 0),
#  'Day': 6,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 12, 0, 0),
#  'Day': 12,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 16, 0, 0),
#  'Day': 16,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 26, 0, 0),
#  'Day': 26,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 10, 27, 0, 0),
#  'Day': 27,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 18, 0, 0),
#  'Day': 18,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 16, 0, 0),
#  'Day': 16,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 21, 0, 0),
#  'Day': 21,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 28, 0, 0),
#  'Day': 28,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 10, 17, 0, 0),
#  'Day': 17,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 6, 0, 0),
#  'Day': 6,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 30, 0, 0),
#  'Day': 30,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 11, 0, 0),
#  'Day': 11,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 16, 0, 0),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 28, 0, 0),
#  'Day': 28,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 30, 0, 0),
#  'Day': 30,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 5, 0, 0),
#  'Day': 5,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 14, 0, 0),
#  'Day': 14,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 22, 0, 0),
#  'Day': 22,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 28, 0, 0),
#  'Day': 28,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 29, 0, 0),
#  'Day': 29,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 25, 0, 0),
#  'Day': 25,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 19, 0, 0),
#  'Day': 19,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 8, 0, 0),
#  'Day': 8,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 12, 0, 0),
#  'Day': 12,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 25, 0, 0),
#  'Day': 25,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 11, 0, 0),
#  'Day': 11,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 19, 0, 0),
#  'Day': 19,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 12, 7, 0, 0),
#  'Day': 7,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 7, 0, 0),
#  'Day': 7,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 2, 0, 0),
#  'Day': 2,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 20, 0, 0),
#  'Day': 20,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 12, 30, 0, 0),
#  'Day': 30,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 9, 5, 0, 0),
#  'Day': 5,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 19, 0, 0),
#  'Day': 19,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 11, 25, 0, 0),
#  'Day': 25,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 23, 0, 0),
#  'Day': 23,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 12, 9, 0, 0),
#  'Day': 9,
#  'Month': 12,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 29, 0, 0),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 8, 29, 0, 0),
#  'Day': 29,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 13, 0, 0),
#  'Day': 13,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 9, 0, 0),
#  'Day': 9,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 9, 2, 0, 0),
#  'Day': 2,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 9, 14, 0, 0),
#  'Day': 14,
#  'Month': 9,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 19, 0, 0),
#  'Day': 19,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 31, 0, 0),
#  'Day': 31,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 24, 0, 0),
#  'Day': 24,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 28, 0, 0),
#  'Day': 28,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 10, 3, 0, 0),
#  'Day': 3,
#  'Month': 10,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 13, 0, 0),
#  'Day': 13,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 10, 0, 0),
#  'Day': 10,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 11, 2, 0, 0),
#  'Day': 2,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 7, 16, 0, 0),
#  'Day': 16,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 30, 0, 0),
#  'Day': 30,
#  'Month': 7,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2020, 8, 21, 0, 0),
#  'Day': 21,
#  'Month': 8,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 8, 10, 0, 0),
#  'Day': 10,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 10, 18, 0, 0),
#  'Day': 18,
#  'Month': 10,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 11, 5, 0, 0),
#  'Day': 5,
#  'Month': 11,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2019, 8, 5, 0, 0),
#  'Day': 5,
#  'Month': 8,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 12, 1, 0, 0),
#  'Day': 1,
#  'Month': 12,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 7, 26, 0, 0),
#  'Day': 26,
#  'Month': 7,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 11, 13, 0, 0),
#  'Day': 13,
#  'Month': 11,
#  'Year': 2020}
# {'Original_date': datetime.datetime(2019, 9, 8, 0, 0),
#  'Day': 8,
#  'Month': 9,
#  'Year': 2019}
# {'Original_date': datetime.datetime(2020, 7, 19, 0, 0),
#  'Day': 19,
#  'Month': 7,
#  'Year': 2020}

# %% [markdown]
# ---
# ### Question -
#
# Difference between current date and the date of enrollment for enrollees.
#
# ----

# %%
# Date expression operators

result = db.hr.aggregate(
        
        # Pipeline
        [            
            # Stage 1
            {
                '$project':{
                            '_id':1,
                            'Difference':{
                                    # Answer returned in milliseconds
                                    '$subtract':['$$NOW', '$date_of_enrollment']
                                         }
                            }
            }
        ])

# Print results
for doc in result:
    pp.pprint(doc)
# Out:
# {'_id': ObjectId('63ce280590fbea39fda03282'), 'Difference': None}
# {'_id': ObjectId('63ce2ad590fbea39fda03283'), 'Difference': None}
# {'_id': ObjectId('63ce2b4c90fbea39fda03285'), 'Difference': None}
# {'_id': ObjectId('60af5db0b2f5ad99212f9464'), 'Difference': 220949708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9465'), 'Difference': 167640908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9466'), 'Difference': 151052108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9467'), 'Difference': 184488908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9468'), 'Difference': 136709708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9469'), 'Difference': 96015308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f946a'), 'Difference': 249029708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f946b'), 'Difference': 147423308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f946c'), 'Difference': 68280908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f946d'), 'Difference': 110962508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f946e'), 'Difference': 228812108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f946f'), 'Difference': 244623308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9470'), 'Difference': 111567308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9471'), 'Difference': 171442508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9472'), 'Difference': 165567308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9473'), 'Difference': 251103308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9474'), 'Difference': 147596108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9475'), 'Difference': 150792908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9476'), 'Difference': 244968908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9477'), 'Difference': 111480908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9478'), 'Difference': 70959308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9479'), 'Difference': 132044108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f947a'), 'Difference': 155976908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f947b'), 'Difference': 124268108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f947c'), 'Difference': 94978508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f947d'), 'Difference': 149842508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f947e'), 'Difference': 222418508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f947f'), 'Difference': 210927308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9480'), 'Difference': 134636108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9481'), 'Difference': 182933708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9482'), 'Difference': 146818508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9483'), 'Difference': 137832908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9484'), 'Difference': 206520908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9485'), 'Difference': 211186508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9486'), 'Difference': 234860108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9487'), 'Difference': 185525708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9488'), 'Difference': 141634508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9489'), 'Difference': 132648908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f948a'), 'Difference': 182588108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f948b'), 'Difference': 131439308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f948c'), 'Difference': 74933708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f948d'), 'Difference': 205397708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f948e'), 'Difference': 245573708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f948f'), 'Difference': 106469708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9490'), 'Difference': 235205708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9491'), 'Difference': 175848908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9492'), 'Difference': 75884108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9493'), 'Difference': 131871308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9494'), 'Difference': 100162508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9495'), 'Difference': 168504908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9496'), 'Difference': 165912908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9497'), 'Difference': 80722508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9498'), 'Difference': 76575308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9499'), 'Difference': 126255308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f949a'), 'Difference': 131612108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f949b'), 'Difference': 77698508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f949c'), 'Difference': 128760908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f949d'), 'Difference': 88498508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f949e'), 'Difference': 167554508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f949f'), 'Difference': 186303308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a0'), 'Difference': 172392908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a1'), 'Difference': 175330508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a2'), 'Difference': 73724108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a3'), 'Difference': 177576908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a4'), 'Difference': 212655308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a5'), 'Difference': 245832908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a6'), 'Difference': 233304908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a7'), 'Difference': 159432908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a8'), 'Difference': 124959308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94a9'), 'Difference': 209199308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94aa'), 'Difference': 105087308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ab'), 'Difference': 81586508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ac'), 'Difference': 101026508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ad'), 'Difference': 79426508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ae'), 'Difference': 201250508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94af'), 'Difference': 182501708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b0'), 'Difference': 190536908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b1'), 'Difference': 178181708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b2'), 'Difference': 188549708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b3'), 'Difference': 127292108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b4'), 'Difference': 76575308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b5'), 'Difference': 183452108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b6'), 'Difference': 241944908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b7'), 'Difference': 250498508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b8'), 'Difference': 145695308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94b9'), 'Difference': 173256908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ba'), 'Difference': 196584908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94bb'), 'Difference': 121330508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94bc'), 'Difference': 236847308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94bd'), 'Difference': 194165708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94be'), 'Difference': 211186508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94bf'), 'Difference': 164271308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c0'), 'Difference': 75106508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c1'), 'Difference': 67157708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c2'), 'Difference': 158482508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c3'), 'Difference': 182674508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c4'), 'Difference': 127637708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c5'), 'Difference': 174380108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c6'), 'Difference': 238229708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c7'), 'Difference': 139388108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c8'), 'Difference': 97743308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94c9'), 'Difference': 97224908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ca'), 'Difference': 220604108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94cb'), 'Difference': 176972108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94cc'), 'Difference': 228466508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94cd'), 'Difference': 197276108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ce'), 'Difference': 213951308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94cf'), 'Difference': 123404108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d0'), 'Difference': 102495308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d1'), 'Difference': 186994508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d2'), 'Difference': 105087308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d3'), 'Difference': 242981708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d4'), 'Difference': 193906508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d5'), 'Difference': 121503308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d6'), 'Difference': 158568908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d7'), 'Difference': 127983308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d8'), 'Difference': 153384908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94d9'), 'Difference': 86770508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94da'), 'Difference': 187167308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94db'), 'Difference': 207471308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94dc'), 'Difference': 101717708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94dd'), 'Difference': 248597708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94de'), 'Difference': 102754508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94df'), 'Difference': 78476108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e0'), 'Difference': 136882508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e1'), 'Difference': 68799308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e2'), 'Difference': 151656908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e3'), 'Difference': 136450508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e4'), 'Difference': 164098508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e5'), 'Difference': 183365708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e6'), 'Difference': 236415308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e7'), 'Difference': 147941708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e8'), 'Difference': 119775308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94e9'), 'Difference': 197967308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ea'), 'Difference': 181378508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94eb'), 'Difference': 167986508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ec'), 'Difference': 66552908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ed'), 'Difference': 123144908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ee'), 'Difference': 118652108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ef'), 'Difference': 126082508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f0'), 'Difference': 212050508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f1'), 'Difference': 235378508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f2'), 'Difference': 145090508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f3'), 'Difference': 201077708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f4'), 'Difference': 149928908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f5'), 'Difference': 190191308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f6'), 'Difference': 200645708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f7'), 'Difference': 96101708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f8'), 'Difference': 193301708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94f9'), 'Difference': 233304908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94fa'), 'Difference': 106210508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94fb'), 'Difference': 147682508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94fc'), 'Difference': 129279308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94fd'), 'Difference': 167122508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94fe'), 'Difference': 67589708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f94ff'), 'Difference': 180428108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9500'), 'Difference': 141634508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9501'), 'Difference': 225788108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9502'), 'Difference': 126860108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9503'), 'Difference': 110703308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9504'), 'Difference': 164012108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9505'), 'Difference': 118911308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9506'), 'Difference': 141634508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9507'), 'Difference': 93250508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9508'), 'Difference': 154853708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9509'), 'Difference': 80290508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f950a'), 'Difference': 110444108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f950b'), 'Difference': 126255308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f950c'), 'Difference': 154680908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f950d'), 'Difference': 203237708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f950e'), 'Difference': 174120908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f950f'), 'Difference': 76834508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9510'), 'Difference': 208335308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9511'), 'Difference': 130834508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9512'), 'Difference': 188290508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9513'), 'Difference': 133426508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9514'), 'Difference': 136018508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9515'), 'Difference': 188290508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9516'), 'Difference': 161333708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9517'), 'Difference': 110789708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9518'), 'Difference': 113900108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9519'), 'Difference': 147855308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f951a'), 'Difference': 113295308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f951b'), 'Difference': 248511308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f951c'), 'Difference': 247906508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f951d'), 'Difference': 158136908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f951e'), 'Difference': 200127308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f951f'), 'Difference': 187340108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9520'), 'Difference': 243068108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9521'), 'Difference': 76920908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9522'), 'Difference': 129192908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9523'), 'Difference': 124008908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9524'), 'Difference': 212309708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9525'), 'Difference': 131439308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9526'), 'Difference': 163925708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9527'), 'Difference': 182760908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9528'), 'Difference': 140511308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9529'), 'Difference': 212568908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f952a'), 'Difference': 201682508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f952b'), 'Difference': 214556108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f952c'), 'Difference': 247215308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f952d'), 'Difference': 138005708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f952e'), 'Difference': 236933708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f952f'), 'Difference': 136796108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9530'), 'Difference': 125909708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9531'), 'Difference': 150879308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9532'), 'Difference': 210668108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9533'), 'Difference': 180946508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9534'), 'Difference': 216111308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9535'), 'Difference': 145695308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9536'), 'Difference': 209976908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9537'), 'Difference': 146818508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9538'), 'Difference': 78389708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9539'), 'Difference': 216543308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f953a'), 'Difference': 197189708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f953b'), 'Difference': 210149708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f953c'), 'Difference': 154940108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f953d'), 'Difference': 191573708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f953e'), 'Difference': 206693708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f953f'), 'Difference': 219480908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9540'), 'Difference': 185266508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9541'), 'Difference': 182328908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9542'), 'Difference': 128674508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9543'), 'Difference': 77612108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9544'), 'Difference': 248424908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9545'), 'Difference': 238661708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9546'), 'Difference': 171788108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9547'), 'Difference': 121676108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9548'), 'Difference': 251621708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9549'), 'Difference': 92472908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f954a'), 'Difference': 73032908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f954b'), 'Difference': 231144908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f954c'), 'Difference': 190623308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f954d'), 'Difference': 133080908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f954e'), 'Difference': 168677708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f954f'), 'Difference': 137746508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9550'), 'Difference': 163234508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9551'), 'Difference': 79253708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9552'), 'Difference': 80981708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9553'), 'Difference': 86856908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9554'), 'Difference': 112172108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9555'), 'Difference': 189932108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9556'), 'Difference': 176453708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9557'), 'Difference': 95583308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9558'), 'Difference': 244277708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9559'), 'Difference': 230453708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f955a'), 'Difference': 206866508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f955b'), 'Difference': 104741708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f955c'), 'Difference': 221640908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f955d'), 'Difference': 129884108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f955e'), 'Difference': 85906508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f955f'), 'Difference': 253608908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9560'), 'Difference': 124527308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9561'), 'Difference': 206780108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9562'), 'Difference': 108716108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9563'), 'Difference': 174293708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9564'), 'Difference': 120812108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9565'), 'Difference': 110876108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9566'), 'Difference': 84351308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9567'), 'Difference': 213951308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9568'), 'Difference': 169628108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9569'), 'Difference': 66725708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f956a'), 'Difference': 252140108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f956b'), 'Difference': 156149708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f956c'), 'Difference': 123490508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f956d'), 'Difference': 220258508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f956e'), 'Difference': 91436108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f956f'), 'Difference': 140252108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9570'), 'Difference': 123058508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9571'), 'Difference': 220344908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9572'), 'Difference': 183797708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9573'), 'Difference': 227343308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9574'), 'Difference': 82364108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9575'), 'Difference': 110098508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9576'), 'Difference': 244882508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9577'), 'Difference': 217407308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9578'), 'Difference': 84178508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9579'), 'Difference': 116060108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f957a'), 'Difference': 249807308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f957b'), 'Difference': 89794508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f957c'), 'Difference': 185180108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f957d'), 'Difference': 75797708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f957e'), 'Difference': 233736908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f957f'), 'Difference': 156236108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9580'), 'Difference': 111221708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9581'), 'Difference': 166085708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9582'), 'Difference': 252399308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9583'), 'Difference': 193128908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9584'), 'Difference': 181378508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9585'), 'Difference': 130402508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9586'), 'Difference': 79685708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9587'), 'Difference': 87807308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9588'), 'Difference': 76575308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9589'), 'Difference': 134117708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f958a'), 'Difference': 179477708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f958b'), 'Difference': 107765708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f958c'), 'Difference': 122799308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f958d'), 'Difference': 220258508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f958e'), 'Difference': 103964108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f958f'), 'Difference': 124440908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9590'), 'Difference': 113036108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9591'), 'Difference': 156668108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9592'), 'Difference': 115541708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9593'), 'Difference': 176540108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9594'), 'Difference': 188031308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9595'), 'Difference': 123404108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9596'), 'Difference': 193128908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9597'), 'Difference': 146386508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9598'), 'Difference': 201250508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9599'), 'Difference': 156322508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f959a'), 'Difference': 189327308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f959b'), 'Difference': 217148108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f959c'), 'Difference': 137055308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f959d'), 'Difference': 167208908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f959e'), 'Difference': 223628108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f959f'), 'Difference': 198485708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a0'), 'Difference': 168936908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a1'), 'Difference': 175935308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a2'), 'Difference': 206261708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a3'), 'Difference': 199781708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a4'), 'Difference': 243240908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a5'), 'Difference': 151138508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a6'), 'Difference': 240130508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a7'), 'Difference': 74328908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a8'), 'Difference': 239871308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95a9'), 'Difference': 151743308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95aa'), 'Difference': 214469708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ab'), 'Difference': 187080908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ac'), 'Difference': 122712908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ad'), 'Difference': 226652108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ae'), 'Difference': 76920908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95af'), 'Difference': 70786508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b0'), 'Difference': 140684108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b1'), 'Difference': 139733708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b2'), 'Difference': 222245708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b3'), 'Difference': 123144908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b4'), 'Difference': 107333708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b5'), 'Difference': 213519308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b6'), 'Difference': 126168908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b7'), 'Difference': 123576908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b8'), 'Difference': 195807308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95b9'), 'Difference': 85820108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ba'), 'Difference': 228812108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95bb'), 'Difference': 68972108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95bc'), 'Difference': 243068108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95bd'), 'Difference': 211013708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95be'), 'Difference': 190709708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95bf'), 'Difference': 109320908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c0'), 'Difference': 92213708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c1'), 'Difference': 217839308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c2'), 'Difference': 200213708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c3'), 'Difference': 190104908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c4'), 'Difference': 177058508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c5'), 'Difference': 144831308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c6'), 'Difference': 142757708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c7'), 'Difference': 239266508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c8'), 'Difference': 131007308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95c9'), 'Difference': 118392908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ca'), 'Difference': 243500108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95cb'), 'Difference': 152175308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95cc'), 'Difference': 209026508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95cd'), 'Difference': 189759308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ce'), 'Difference': 138610508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95cf'), 'Difference': 185525708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d0'), 'Difference': 116319308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d1'), 'Difference': 98952908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d2'), 'Difference': 190882508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d3'), 'Difference': 157791308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d4'), 'Difference': 159778508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d5'), 'Difference': 214037708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d6'), 'Difference': 232181708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d7'), 'Difference': 218184908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d8'), 'Difference': 230108108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95d9'), 'Difference': 163148108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95da'), 'Difference': 250325708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95db'), 'Difference': 143708108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95dc'), 'Difference': 128156108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95dd'), 'Difference': 246783308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95de'), 'Difference': 135154508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95df'), 'Difference': 129884108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e0'), 'Difference': 99471308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e1'), 'Difference': 153989708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e2'), 'Difference': 72255308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e3'), 'Difference': 89362508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e4'), 'Difference': 205570508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e5'), 'Difference': 103445708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e6'), 'Difference': 241772108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e7'), 'Difference': 149669708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e8'), 'Difference': 91176908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95e9'), 'Difference': 200040908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ea'), 'Difference': 97829708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95eb'), 'Difference': 174639308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ec'), 'Difference': 155717708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ed'), 'Difference': 90485708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ee'), 'Difference': 250930508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ef'), 'Difference': 206434508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f0'), 'Difference': 236760908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f1'), 'Difference': 237365708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f2'), 'Difference': 247042508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f3'), 'Difference': 250671308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f4'), 'Difference': 201336908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f5'), 'Difference': 117183308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f6'), 'Difference': 108024908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f7'), 'Difference': 144831308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f8'), 'Difference': 79944908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95f9'), 'Difference': 201164108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95fa'), 'Difference': 134895308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95fb'), 'Difference': 221381708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95fc'), 'Difference': 85388108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95fd'), 'Difference': 164098508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95fe'), 'Difference': 218098508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f95ff'), 'Difference': 249980108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9600'), 'Difference': 228120908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9601'), 'Difference': 74760908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9602'), 'Difference': 222245708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9603'), 'Difference': 94719308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9604'), 'Difference': 219308108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9605'), 'Difference': 161160908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9606'), 'Difference': 106210508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9607'), 'Difference': 77180108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9608'), 'Difference': 212223308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9609'), 'Difference': 94632908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f960a'), 'Difference': 248856908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f960b'), 'Difference': 141202508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f960c'), 'Difference': 185439308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f960d'), 'Difference': 73032908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f960e'), 'Difference': 85992908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f960f'), 'Difference': 202460108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9610'), 'Difference': 238316108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9611'), 'Difference': 151311308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9612'), 'Difference': 243500108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9613'), 'Difference': 77439308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9614'), 'Difference': 182156108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9615'), 'Difference': 214556108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9616'), 'Difference': 188204108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9617'), 'Difference': 115714508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9618'), 'Difference': 214901708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9619'), 'Difference': 74242508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f961a'), 'Difference': 201768908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f961b'), 'Difference': 152693708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f961c'), 'Difference': 91090508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f961d'), 'Difference': 67589708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f961e'), 'Difference': 135672908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f961f'), 'Difference': 188549708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9620'), 'Difference': 147336908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9621'), 'Difference': 151484108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9622'), 'Difference': 186994508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9623'), 'Difference': 78994508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9624'), 'Difference': 160728908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9625'), 'Difference': 233218508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9626'), 'Difference': 98866508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9627'), 'Difference': 239007308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9628'), 'Difference': 103964108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9629'), 'Difference': 71304908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f962a'), 'Difference': 222418508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f962b'), 'Difference': 99384908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f962c'), 'Difference': 209890508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f962d'), 'Difference': 243240908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f962e'), 'Difference': 82882508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f962f'), 'Difference': 89016908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9630'), 'Difference': 110703308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9631'), 'Difference': 195116108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9632'), 'Difference': 216111308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9633'), 'Difference': 237279308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9634'), 'Difference': 172047308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9635'), 'Difference': 118652108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9636'), 'Difference': 207903308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9637'), 'Difference': 201768908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9638'), 'Difference': 220085708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9639'), 'Difference': 193042508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f963a'), 'Difference': 250066508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f963b'), 'Difference': 143880908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f963c'), 'Difference': 71996108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f963d'), 'Difference': 240389708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f963e'), 'Difference': 108629708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f963f'), 'Difference': 202719308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9640'), 'Difference': 229589708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9641'), 'Difference': 237279308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9642'), 'Difference': 128760908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9643'), 'Difference': 115628108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9644'), 'Difference': 131266508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9645'), 'Difference': 135068108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9646'), 'Difference': 135586508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9647'), 'Difference': 253004108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9648'), 'Difference': 108975308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9649'), 'Difference': 194684108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f964a'), 'Difference': 166690508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f964b'), 'Difference': 182674508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f964c'), 'Difference': 185007308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f964d'), 'Difference': 70959308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f964e'), 'Difference': 160642508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f964f'), 'Difference': 185612108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9650'), 'Difference': 85474508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9651'), 'Difference': 91608908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9652'), 'Difference': 188981708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9653'), 'Difference': 184056908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9654'), 'Difference': 72168908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9655'), 'Difference': 66552908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9656'), 'Difference': 154248908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9657'), 'Difference': 163061708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9658'), 'Difference': 215938508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9659'), 'Difference': 120380108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f965a'), 'Difference': 76488908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f965b'), 'Difference': 151311308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f965c'), 'Difference': 229503308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f965d'), 'Difference': 225874508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f965e'), 'Difference': 209285708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f965f'), 'Difference': 170405708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9660'), 'Difference': 150447308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9661'), 'Difference': 97743308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9662'), 'Difference': 142325708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9663'), 'Difference': 200213708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9664'), 'Difference': 244709708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9665'), 'Difference': 136796108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9666'), 'Difference': 70095308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9667'), 'Difference': 134549708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9668'), 'Difference': 116319308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9669'), 'Difference': 106728908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f966a'), 'Difference': 156581708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f966b'), 'Difference': 129365708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f966c'), 'Difference': 211964108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f966d'), 'Difference': 253176908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f966e'), 'Difference': 237279308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f966f'), 'Difference': 233996108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9670'), 'Difference': 214556108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9671'), 'Difference': 131612108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9672'), 'Difference': 136709708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9673'), 'Difference': 121416908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9674'), 'Difference': 209717708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9675'), 'Difference': 216543308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9676'), 'Difference': 149410508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9677'), 'Difference': 133599308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9678'), 'Difference': 175330508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9679'), 'Difference': 207644108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f967a'), 'Difference': 248597708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f967b'), 'Difference': 226997708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f967c'), 'Difference': 212136908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f967d'), 'Difference': 195029708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f967e'), 'Difference': 218357708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f967f'), 'Difference': 246696908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9680'), 'Difference': 174034508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9681'), 'Difference': 166172108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9682'), 'Difference': 157445708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9683'), 'Difference': 235378508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9684'), 'Difference': 86079308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9685'), 'Difference': 217234508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9686'), 'Difference': 75020108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9687'), 'Difference': 98434508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9688'), 'Difference': 229848908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9689'), 'Difference': 230972108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f968a'), 'Difference': 159951308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f968b'), 'Difference': 92213708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f968c'), 'Difference': 70527308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f968d'), 'Difference': 97829708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f968e'), 'Difference': 117788108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f968f'), 'Difference': 148978508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9690'), 'Difference': 167122508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9691'), 'Difference': 173084108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9692'), 'Difference': 102754508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9693'), 'Difference': 150188108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9694'), 'Difference': 88671308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9695'), 'Difference': 251880908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9696'), 'Difference': 171442508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9697'), 'Difference': 229244108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9698'), 'Difference': 153903308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f9699'), 'Difference': 122194508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f969a'), 'Difference': 148546508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f969b'), 'Difference': 73205708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f969c'), 'Difference': 68885708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f969d'), 'Difference': 143276108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f969e'), 'Difference': 98434508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f969f'), 'Difference': 135240908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a0'), 'Difference': 144226508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a1'), 'Difference': 166172108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a2'), 'Difference': 81672908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a3'), 'Difference': 184575308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a4'), 'Difference': 120380108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a5'), 'Difference': 173948108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a6'), 'Difference': 224751308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a7'), 'Difference': 202546508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a8'), 'Difference': 83055308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96a9'), 'Difference': 196757708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96aa'), 'Difference': 89621708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ab'), 'Difference': 98866508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ac'), 'Difference': 144744908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ad'), 'Difference': 67157708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ae'), 'Difference': 116751308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96af'), 'Difference': 116664908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b0'), 'Difference': 193215308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b1'), 'Difference': 181032908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b2'), 'Difference': 235810508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b3'), 'Difference': 222677708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b4'), 'Difference': 66639308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b5'), 'Difference': 237970508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b6'), 'Difference': 136364108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b7'), 'Difference': 69231308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b8'), 'Difference': 208940108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96b9'), 'Difference': 228120908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ba'), 'Difference': 236069708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96bb'), 'Difference': 154940108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96bc'), 'Difference': 136882508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96bd'), 'Difference': 129797708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96be'), 'Difference': 250325708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96bf'), 'Difference': 192610508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c0'), 'Difference': 156495308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c1'), 'Difference': 202460108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c2'), 'Difference': 140424908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c3'), 'Difference': 158309708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c4'), 'Difference': 71996108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c5'), 'Difference': 161852108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c6'), 'Difference': 138610508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c7'), 'Difference': 95496908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c8'), 'Difference': 184661708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96c9'), 'Difference': 160469708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ca'), 'Difference': 226652108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96cb'), 'Difference': 190191308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96cc'), 'Difference': 215420108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96cd'), 'Difference': 148719308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ce'), 'Difference': 179132108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96cf'), 'Difference': 95669708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d0'), 'Difference': 196498508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d1'), 'Difference': 252744908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d2'), 'Difference': 136450508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d3'), 'Difference': 188204108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d4'), 'Difference': 66466508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d5'), 'Difference': 198053708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d6'), 'Difference': 168504908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d7'), 'Difference': 237538508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d8'), 'Difference': 128069708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96d9'), 'Difference': 121762508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96da'), 'Difference': 156149708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96db'), 'Difference': 229848908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96dc'), 'Difference': 118738508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96dd'), 'Difference': 74069708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96de'), 'Difference': 218530508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96df'), 'Difference': 133253708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e0'), 'Difference': 172738508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e1'), 'Difference': 107592908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e2'), 'Difference': 116924108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e3'), 'Difference': 159346508302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e4'), 'Difference': 114677708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e5'), 'Difference': 107160908302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e6'), 'Difference': 192005708302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e7'), 'Difference': 152780108302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e8'), 'Difference': 239007308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96e9'), 'Difference': 102063308302}
# {'_id': ObjectId('60af5db0b2f5ad99212f96ea'), 'Difference': 153471308302}
# ...
# {'_id': ObjectId('60af5db5b2f5ad99212fdb43'), 'Difference': 208508108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb44'), 'Difference': 251362508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb45'), 'Difference': 192783308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb46'), 'Difference': 209026508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb47'), 'Difference': 218876108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb48'), 'Difference': 133512908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb49'), 'Difference': 101544908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb4a'), 'Difference': 92645708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb4b'), 'Difference': 109148108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb4c'), 'Difference': 209112908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb4d'), 'Difference': 75452108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb4e'), 'Difference': 234514508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb4f'), 'Difference': 172652108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb50'), 'Difference': 95064908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb51'), 'Difference': 128588108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb52'), 'Difference': 205829708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb53'), 'Difference': 203669708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb54'), 'Difference': 214469708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb55'), 'Difference': 139215308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb56'), 'Difference': 202892108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb57'), 'Difference': 131093708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb58'), 'Difference': 193733708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb59'), 'Difference': 141720908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb5a'), 'Difference': 243586508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb5b'), 'Difference': 142930508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb5c'), 'Difference': 165480908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb5d'), 'Difference': 169023308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb5e'), 'Difference': 74415308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb5f'), 'Difference': 97138508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb60'), 'Difference': 139733708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb61'), 'Difference': 219308108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb62'), 'Difference': 123663308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb63'), 'Difference': 100335308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb64'), 'Difference': 210322508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb65'), 'Difference': 182847308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb66'), 'Difference': 78303308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb67'), 'Difference': 246092108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb68'), 'Difference': 168936908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb69'), 'Difference': 166690508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb6a'), 'Difference': 166344908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb6b'), 'Difference': 216197708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb6c'), 'Difference': 252226508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb6d'), 'Difference': 183624908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb6e'), 'Difference': 212482508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb6f'), 'Difference': 130834508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb70'), 'Difference': 94114508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb71'), 'Difference': 240648908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb72'), 'Difference': 171528908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb73'), 'Difference': 228898508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb74'), 'Difference': 80117708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb75'), 'Difference': 161074508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb76'), 'Difference': 231144908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb77'), 'Difference': 130488908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb78'), 'Difference': 178527308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb79'), 'Difference': 99903308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb7a'), 'Difference': 211618508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb7b'), 'Difference': 235810508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb7c'), 'Difference': 201596108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb7d'), 'Difference': 200213708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb7e'), 'Difference': 162197708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb7f'), 'Difference': 90485708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb80'), 'Difference': 241340108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb81'), 'Difference': 128847308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb82'), 'Difference': 131439308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb83'), 'Difference': 102236108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb84'), 'Difference': 240130508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb85'), 'Difference': 181724108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb86'), 'Difference': 114677708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb87'), 'Difference': 245832908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb88'), 'Difference': 88152908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb89'), 'Difference': 208594508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb8a'), 'Difference': 244709708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb8b'), 'Difference': 192610508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb8c'), 'Difference': 104396108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb8d'), 'Difference': 134376908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb8e'), 'Difference': 233650508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb8f'), 'Difference': 118220108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb90'), 'Difference': 88757708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb91'), 'Difference': 188981708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb92'), 'Difference': 94546508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb93'), 'Difference': 206952908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb94'), 'Difference': 147855308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb95'), 'Difference': 88239308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb96'), 'Difference': 135327308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb97'), 'Difference': 139992908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb98'), 'Difference': 189154508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb99'), 'Difference': 118911308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb9a'), 'Difference': 246696908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb9b'), 'Difference': 148805708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb9c'), 'Difference': 248338508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb9d'), 'Difference': 66639308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb9e'), 'Difference': 101112908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdb9f'), 'Difference': 165567308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba0'), 'Difference': 113640908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba1'), 'Difference': 109061708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba2'), 'Difference': 224405708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba3'), 'Difference': 85042508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba4'), 'Difference': 252226508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba5'), 'Difference': 145608908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba6'), 'Difference': 116664908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba7'), 'Difference': 106901708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba8'), 'Difference': 248856908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdba9'), 'Difference': 182847308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbaa'), 'Difference': 157704908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbab'), 'Difference': 117615308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbac'), 'Difference': 101804108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbad'), 'Difference': 88671308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbae'), 'Difference': 193560908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbaf'), 'Difference': 111221708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb0'), 'Difference': 107247308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb1'), 'Difference': 205656908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb2'), 'Difference': 202373708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb3'), 'Difference': 78389708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb4'), 'Difference': 84092108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb5'), 'Difference': 214124108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb6'), 'Difference': 219394508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb7'), 'Difference': 76488908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb8'), 'Difference': 156236108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbb9'), 'Difference': 218184908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbba'), 'Difference': 137832908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbbb'), 'Difference': 82018508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbbc'), 'Difference': 247388108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbbd'), 'Difference': 95756108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbbe'), 'Difference': 247733708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbbf'), 'Difference': 177231308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc0'), 'Difference': 194079308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc1'), 'Difference': 231663308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc2'), 'Difference': 145349708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc3'), 'Difference': 238488908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc4'), 'Difference': 189240908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc5'), 'Difference': 208508108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc6'), 'Difference': 142325708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc7'), 'Difference': 207384908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc8'), 'Difference': 189932108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbc9'), 'Difference': 143103308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbca'), 'Difference': 131784908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbcb'), 'Difference': 210754508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbcc'), 'Difference': 211877708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbcd'), 'Difference': 140424908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbce'), 'Difference': 241426508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbcf'), 'Difference': 113727308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd0'), 'Difference': 222072908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd1'), 'Difference': 215852108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd2'), 'Difference': 113295308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd3'), 'Difference': 204533708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd4'), 'Difference': 248511308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd5'), 'Difference': 171788108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd6'), 'Difference': 239007308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd7'), 'Difference': 249634508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd8'), 'Difference': 219826508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbd9'), 'Difference': 201077708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbda'), 'Difference': 195461708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbdb'), 'Difference': 197880908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbdc'), 'Difference': 232959308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbdd'), 'Difference': 228034508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbde'), 'Difference': 184834508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbdf'), 'Difference': 170319308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe0'), 'Difference': 165567308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe1'), 'Difference': 199263308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe2'), 'Difference': 129970508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe3'), 'Difference': 158396108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe4'), 'Difference': 243327308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe5'), 'Difference': 109061708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe6'), 'Difference': 117356108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe7'), 'Difference': 71477708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe8'), 'Difference': 101544908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbe9'), 'Difference': 253090508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbea'), 'Difference': 201855308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbeb'), 'Difference': 230367308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbec'), 'Difference': 216629708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbed'), 'Difference': 115023308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbee'), 'Difference': 138524108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbef'), 'Difference': 109493708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf0'), 'Difference': 176280908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf1'), 'Difference': 139733708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf2'), 'Difference': 67676108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf3'), 'Difference': 140943308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf4'), 'Difference': 227861708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf5'), 'Difference': 117356108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf6'), 'Difference': 193992908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf7'), 'Difference': 154940108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf8'), 'Difference': 213951308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbf9'), 'Difference': 213605708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbfa'), 'Difference': 79858508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbfb'), 'Difference': 235896908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbfc'), 'Difference': 187253708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbfd'), 'Difference': 163493708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbfe'), 'Difference': 110357708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdbff'), 'Difference': 225183308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc00'), 'Difference': 69231308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc01'), 'Difference': 139992908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc02'), 'Difference': 164616908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc03'), 'Difference': 224837708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc04'), 'Difference': 148373708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc05'), 'Difference': 106556108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc06'), 'Difference': 192092108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc07'), 'Difference': 116664908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc08'), 'Difference': 235896908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc09'), 'Difference': 94373708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc0a'), 'Difference': 79340108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc0b'), 'Difference': 220690508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc0c'), 'Difference': 95151308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc0d'), 'Difference': 92300108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc0e'), 'Difference': 201941708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc0f'), 'Difference': 183365708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc10'), 'Difference': 209372108302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc11'), 'Difference': 235378508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc12'), 'Difference': 252312908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc13'), 'Difference': 86338508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc14'), 'Difference': 96274508302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc15'), 'Difference': 236933708302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc16'), 'Difference': 150879308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc17'), 'Difference': 146127308302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc18'), 'Difference': 149928908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc19'), 'Difference': 190968908302}
# {'_id': ObjectId('60af5db5b2f5ad99212fdc1a'), 'Difference': 119775308302}

# %% [markdown]
# ----
# ----
# ### Exercise 1 -
#
# How many enrollees from STEM discipline enrolled in the year 2019?
#
# ----

# %% [markdown]
# ----
# ### Exercise 2 -
#
# Count the number of enrollees from 'Business Degree' or 'Humanities' discipline who joined training in the first week of any year.
#
# *Hint - use [$isoWeek](https://docs.mongodb.com/manual/reference/operator/aggregation/isoWeek/#-isoweek--aggregation-) operator.*
#
# ----
