# %% [markdown]
# # Geospatial Index

# %% [markdown]
# ---
# ### [Geospatial Index](https://docs.mongodb.com/manual/geospatial-queries/)
#
# - Support queries on geospatial data.
# > - Think of GPS location in Google maps, Uber, Zomato, etc.
#
# - Support objects for point, line, polygon, etc.
#
# - Can find nearest point to a given location, point existing within a bounding geometry, and more.
#
# ----

# %% [markdown]
# ### Connect to local server
#
# ---

# %%
# Importing the required libraries
import pymongo

import pprint as pp
pp.sorted = lambda x, key=None: x

# %%
# Connect to local host
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
# Connect to database
db = client['nyc']

# %%
# Sample document
pp.pprint(db.airbnb.find_one())
# Out:
# {'_id': ObjectId('60c21bf5b653d40e79b4a7d0'),
#  'accom_id': 2595,
#  'description': 'Skylit Midtown Castle',
#  'host': {'id': 2845,
#           'name': 'Jennifer',
#           'listings_count': 3,
#           'neighbourhood_list': ['Midtown', "Hell's Kitchen"]},
#  'neighbourhood': {'name': 'Midtown', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.98559, 40.75356]},
#  'room_type': 'Entire home/apt',
#  'price': 150,
#  'minimum_nights': 30,
#  'reviews': {'number_of_reviews': 48,
#              'last_review': datetime.datetime(2019, 11, 4, 0, 0),
#              'reviews_per_month': 0.35},
#  'availability_365': 365}

# %% [markdown]
# ---
# **Drop previous indexes.**
#
# ---

# %%
db.airbnb.drop_indexes()

# %% [markdown]
# ---
# **Create geospatial index.**
#
# ----

# %%
# Create geospatial index
db.airbnb.create_index([
                        ('location', '2dsphere')
                    ])
# Out:
# 'location_2dsphere'

# %% [markdown]
# ----
# ### $nearSphere operator
#
# Suppose you want to find an accomodation close to location -73.93414657 longitude and 40.82302903 latitude.
#
# [$nearSphere](https://docs.mongodb.com/manual/reference/operator/query/nearSphere/#mongodb-query-op.-nearSphere) specifies a point for which a geospatial query returns the documents from nearest to farthest.
#
# ----

# %%
# Query using geospatial index
pp.pprint(
    db.airbnb.find_one({
                        'location': {
                                        '$nearSphere': {
                                                            '$geometry': {
                                                                            'type': 'Point',
                                                                            'coordinates': [-73.93414657, 40.82302903]
                                                                        }
                                                        }
                                                    }
                        })
)
# Out:
# {'_id': ObjectId('60c21bfdb653d40e79b51958'),
#  'accom_id': 42402892,
#  'description': 'Peaceful',
#  'host': {'id': 337459786,
#           'name': 'Empress',
#           'listings_count': 1,
#           'neighbourhood_list': ['Harlem']},
#  'neighbourhood': {'name': 'Harlem', 'group': 'Manhattan'},
#  'location': {'type': 'Point', 'coordinates': [-73.93623, 40.82389]},
#  'room_type': 'Private room',
#  'price': 49,
#  'minimum_nights': 36,
#  'reviews': {'number_of_reviews': 0,
#              'last_review': nan,
#              'reviews_per_month': nan},
#  'availability_365': 365}

# %% [markdown]
# ---
# **Query using minimum or maximum distances to narrow down the search parameter.**
#
# `$minDistance` filters the results of query to those documents that are at least the specified distance from the center point. While `$maxDistance` determines the maximum distance to look for. Both fields take values in meters.
#
# ---

# %%
# Query using minDistance
len(list(db.airbnb.find({
                'location': {
                                '$nearSphere': {
                                                    '$geometry': {
                                                                    'type': 'Point',
                                                                    'coordinates': [-73.93414657, 40.82302903]
                                                                },
                                                    '$maxDistance': 1500
                                                }
                                            }
            })))#.count()
# Out:
# 1117

# %% [markdown]
# ---
# For exclusion certain documents based on location, we can use `$minDistance`.
#
# ---

# %%
# Query minDistance and maxDistance
len(list(db.airbnb.find({
                'location': {
                                '$nearSphere': {
                                                    '$geometry': {
                                                        'type': 'Point',
                                                        'coordinates': [-73.93414657, 40.82302903]
                                                    },
                                                    '$minDistance': 1000,
                                                    '$maxDistance': 1500
                                                }
                            }
            })))#.count()
# Out:
# 689

# %% [markdown]
# ----
# ### Neighbourhood data
#
# New York City neighbourhood boundaries data.
#
# Website - https://opendata.cityofnewyork.us/
#
# ----

# %%
# # Restore neighbourhoods data
# !mongorestore --db nyc --collection neighbourhoods "C:/Users/parin/Documents/AV/MongoDB/Course Handouts/Module 7 - Indexing in MongoDB/Notebook dataset/nyc_neighbourhoods/nyc/neighbourhoods.bson"

#C:\Users\parin>mongorestore --db nyc --collection neighbourhoods "C:/Users/parin/Documents/AV/MongoDB/Course Handouts/Module 7 - Indexing in MongoDB/Notebook dataset/nyc_neighbourhoods/nyc/neighbourhoods.bson"

# %%
# Collections
db.list_collection_names()
# Out:
# ['neighbourhood', 'airbnb', 'neighbourhoods']

# %%
# Sample document
pp.pprint(
    db.neighbourhoods.find_one()
)
# Out:
# {'_id': ObjectId('60bf31520914cc69b40dd71e'),
#  'type': 'Feature',
#  'properties': {'ntacode': 'BX63',
#                 'shape_area': '19379048.8116',
#                 'county_fips': '005',
#                 'ntaname': 'West Concourse',
#                 'shape_leng': '28500.1688303',
#                 'boro_name': 'Bronx',
#                 'boro_code': '2'},
#  'geometry': {'type': 'MultiPolygon',
#               'coordinates': [[[[-73.9119181232027, 40.84325788668494],
#                                 [-73.9119464821854, 40.84317571365838],
#                                 [-73.91198635358123, 40.843057098087755],
#                                 [-73.91222180466877, 40.84235659120049],
#                                 [-73.91240381713898, 40.841816496608914],
#                                 [-73.91246930262152, 40.84162025687984],
#                                 [-73.91262256160424, 40.84115715928204],
#                                 [-73.91269769187517, 40.840930129302016],
#                                 [-73.91277823162264, 40.840691064592754],
#                                 [-73.91296000882072, 40.84019622853909],
#                                 [-73.91313156347168, 40.83981054013581],
#                                 [-73.91371372726749, 40.83880893480774],
#                                 [-73.91377104974535, 40.83872164766109],
#                                 [-73.91383125912098, 40.838639045435855],
#                                 [-73.91423754080526, 40.83810879565886],
#                                 [-73.91477300591481, 40.83751410085955],
#                                 [-73.91531596608954, 40.83694742354377],
#                                 [-73.91587067532252, 40.836393594243106],
#                                 [-73.91647433338245, 40.835779030895935],
#                                 [-73.91667316740136, 40.83556740537188],
#                                 [-73.91720735744661, 40.835021513933015],
#                                 [-73.91763739188319, 40.83458204246822],
#                                 [-73.9176797479621, 40.83453875570221],
#                                 [-73.91770299053982, 40.83451500851282],
#                                 [-73.91773114976955, 40.83448623056323],
#                                 [-73.91778665897066, 40.83442951168606],
#                                 [-73.91839346704676, 40.83380941190167],
#                                 [-73.91856785826057, 40.833612014168935],
#                                 [-73.91903136702281, 40.8330873492922],
#                                 [-73.91949947117882, 40.83247949245447],
#                                 [-73.9198608938979, 40.83194722683435],
#                                 [-73.92046219239054, 40.83091259393521],
#                                 [-73.92085164103507, 40.83021227788625],
#                                 [-73.92087639003697, 40.8301677103453],
#                                 [-73.92117588349309, 40.82962792968307],
#                                 [-73.91938459876796, 40.838076913553515],
#                                 [-73.91930863311701, 40.838126322857164],
#                                 [-73.91916265213858, 40.83825371248935],
#                                 [-73.91901668296427, 40.8383810930639],
#                                 [-73.91859196051547, 40.83898208991599],
#                                 [-73.9181372749649, 40.83960685394312],
#                                 [-73.91768361901806, 40.84022549553236],
#                                 [-73.91729851615048, 40.840766118367036],
#                                 [-73.91689176304536, 40.84134725715196],
#                                 [-73.91618344432074, 40.84233490025414],
#                                 [-73.9176874591774, 40.84223933337094],
#                                 [-73.9179496521323, 40.84222957060769],
#                                 [-73.91798075212289, 40.84266741383509],
#                                 [-73.91798848469794, 40.84274888230691],
#                                 [-73.91798774685338, 40.84283056022214],
#                                 [-73.91797854313926, 40.842911940454655],
#                                 [-73.91796093066937, 40.842992517724824],
#                                 [-73.91793501917981, 40.84307179139039],
#                                 [-73.91790096918804, 40.84314926962751],
#                                 [-73.91785899207835, 40.84322447138315],
#                                 [-73.9178093484561, 40.84329692973708],
#                                 [-73.91771300737066, 40.843387278287196],
#                                 [-73.9176284855232, 40.8434867059352],
#                                 [-73.91755786158764, 40.843593802302486],
#                                 [-73.91750281959976, 40.84370681816343],
#                                 [-73.9174644972856, 40.843823760822026],
#                                 [-73.91744344449876, 40.84394246092128],
#                                 [-73.9174395704655, 40.84406076823889],
#                                 [-73.91745219816346, 40.844176630294406],
#                                 [-73.91747944061864, 40.8442522948959],
#                                 [-73.91749951174705, 40.84432924168007],
#                                 [-73.9175123094164, 40.84440707919765],
#                                 [-73.91751776849561, 40.84448541146656],
#                                 [-73.91751586118677, 40.84456383998639],
#                                 [-73.91750659701007, 40.84464196562159],
#                                 [-73.91749002325068, 40.844719391056806],
#                                 [-73.91746622419969, 40.84479572240208],
#                                 [-73.91743532090693, 40.84487057133212],
#                                 [-73.91739747056556, 40.844943557061896],
#                                 [-73.91732494876602, 40.84505748284694],
#                                 [-73.91728719351066, 40.84510408615949],
#                                 [-73.91697152437618, 40.845115246126525],
#                                 [-73.9168430937648, 40.845070778771394],
#                                 [-73.91611927084668, 40.844855793071304],
#                                 [-73.91586647842541, 40.844793925076836],
#                                 [-73.91474419406394, 40.84434250389378],
#                                 [-73.91385799418651, 40.8439787941701],
#                                 [-73.91302876945585, 40.84364162132417],
#                                 [-73.9129380323358, 40.843597555115984],
#                                 [-73.9121122217203, 40.84326034204364],
#                                 [-73.9119181232027, 40.84325788668494]]]]}}

# %%
# Create geospatial index
db.neighbourhood.create_index([('geometry', '2dsphere')])
# Out:
# 'geometry_2dsphere'

# %% [markdown]
# ---
# ### $geoWithin operator
#
# Suppose you need to find out the number of accomodations within a specific neighbourhood.
#
# You would need to use [$geoWithin](https://docs.mongodb.com/manual/reference/operator/query/geoWithin/#mongodb-query-op.-geoWithin) that selects documents with geospatial data that exists entirely within a specified shape.
#
# Find how many accomodations fall in the `Upper West Side` neighbourhood.
#
# ---

# %%
# Query
pp.pprint(
        db.neighbourhoods.find_one({
                                'properties.ntaname': 'Upper West Side'
                            })
)
# Out:
# {'_id': ObjectId('60bf31520914cc69b40dd6c0'),
#  'type': 'Feature',
#  'properties': {'ntacode': 'MN12',
#                 'shape_area': '34379942.4562',
#                 'county_fips': '061',
#                 'ntaname': 'Upper West Side',
#                 'shape_leng': '29160.206532',
#                 'boro_name': 'Manhattan',
#                 'boro_code': '1'},
#  'geometry': {'type': 'MultiPolygon',
#               'coordinates': [[[[
#     [-73.97448722520987, 40.80105742889681],
#     [-73.97414361823468, 40.801516895341166],
#     [-73.9739409836671, 40.80180902536142],
#     [-73.97389989052462, 40.8018898635312],
#     [-73.9737747724601, 40.80204584594857],
#     [-73.97372060455763, 40.802167815280235],
#     [-73.97361322463902, 40.80229685988716],
#     [-73.9735422772157, 40.8023564112503],
#     [-73.97336671067802, 40.80263011334648],
#     [-73.97320518045738, 40.80283005827629],
#     [-73.97312859120993, 40.80297471550865],
#     [-73.97307070537943, 40.8030555484474],
#     [-73.97303522902074, 40.803073973741924],
#     [-73.97292317001968, 40.80324982284385],
#     [-73.97286807262154, 40.803320734176026],
#     [-73.9728717908152, 40.80335618764529],
#     [-73.9727990775659, 40.80332915965665],
#     [-73.97265744745971, 40.80327651416273],
#     [-73.97257779872238, 40.80324718427396],
#     [-73.97250022180596, 40.80321661262815],
#     [-73.9715038100381, 40.80283773617444],
#     [-73.97032589767365, 40.80238456087054],
#     [-73.97027400465872, 40.802359036994034],
#     [-73.97021594793262, 40.80233585148788],
#     [-73.9700474216526, 40.80226501033981],
#     [-73.96990233721267, 40.80220261630643],
#     [-73.96950085630162, 40.802029954217176],
#     [-73.96939584282657, 40.801984791017475],
#     [-73.9685836074654, 40.80163547026632],
#     [-73.96798532597124, 40.80139736799748],
#     [-73.96787565374989, 40.801353370264366],
#     [-73.9677608983512, 40.80130767967453],
#     [-73.9672027526682, 40.80106841103663],
#     [-73.96703330265001, 40.800996790065824],
#     [-73.96693654879286, 40.800955895009196],
#     [-73.96680188273935, 40.80089897626584],
#     [-73.9657105864203, 40.80043707061478],
#     [-73.96460478989536, 40.799971380498214],
#     [-73.96432680321747, 40.79985414601452],
#     [-73.96286668258087, 40.79923370368832],
#     [-73.96147779901374, 40.798654156436385],
#     [-73.96003018437119, 40.798038107394326]]]]}

# %% [markdown]
# ----
#
# Find all the documents that fall within the neighbourhood boundary in the airbnb collection.
#
# ---

# %%
# Number of accomodations that fall within the neighbourhood
len(list(db.airbnb.find({
                'location': {
                                '$geoWithin': {
                                                '$geometry': neighbourhood_loc
                                            }
                            }
            })))#.count()
# Out:
# 886

# %%
# Documents
cur = db.airbnb.find({
                        'location': {
                                        '$geoWithin': {
                                            '$geometry': neighbourhood_loc
                                                    }
                                    }
                    },
                    {
                        'neighbourhood':1,
                        '_id':0,
                        'accom_id':1
                    })

for doc in cur:
    pp.pprint(doc)
# Out:
# {'accom_id': 107895,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 2283143,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6972192,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 16846366,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6972089,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 5541897,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 5033691,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 5081207,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4905248,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 5034136,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4905118,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 16444320,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6985434,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 397034,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 24535821,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 24493582,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6985888,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 43489765,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 45822475,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4921548,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 26527791,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6626894,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 19181881,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4762718,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 1965712,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 44416196,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 16333020,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 249804,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 30739837,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 5028264,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 13716080,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 45432388,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 7246159,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 17974244,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4782252,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 1987627,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 45994519,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 16467731,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 11240650,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 39274053,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 9296089,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 42517630,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6357527,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4121110,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 20263650,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4823910,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 13163474,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4058701,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 25814039,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 25276349,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 14280778,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 5773199,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6425850,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 3876850,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 27544396,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 45781965,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 2863589,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 42851131,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 

#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 20814478,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 42711518,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 13292087,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 33400953,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 45864124,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6652353,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 42472907,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 263888,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 10021643,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 2135766,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 17667639,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 24772454,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 10930279,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 27501755,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 1294973,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 702551,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 6200613,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 26609429,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 17464151,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 8663101,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 46471494,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 35463986,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 9984143,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 4549555,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 10919968,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 9786769,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 18209795,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 9624825,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 779838,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 21649172,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 21355005,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 48884964,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 43786439,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 18763188,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 44864336,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}
# {'accom_id': 15721376,
#  'neighbourhood': {'name': 'Upper West Side', 'group': 'Manhattan'}}

# %% [markdown]
# ---
# ### Aggregation Pipeline
#
# We can calculate `$nearSphere` queries in aggregate pipeline suing [$geoNear](https://docs.mongodb.com/manual/reference/operator/aggregation/geoNear/#-geonear--aggregation-) operator.
#
# It outputs documents in order of nearest to farthest from a specified point.
#
# **Syntax -** `{ $geoNear: { <geoNear options> } }`
#
# The `$geoNear` pipeline operator takes advantage of a geospatial index. When using `$geoNear`, the `$geoNear` pipeline operation must appear as the first stage in an aggregation pipeline.
#
#
# ----

# %% [markdown]
# For example, finding all documents in airbnb collection nearest to `[-73.93414657, 40.82302903]` between 1000 and 5000 meters from it.
#
# ---

# %%
# Aggregate pipeline
cur = db.airbnb.aggregate([
                        # geoNear
                        {
                            '$geoNear':{
                                            # Point
                                            'near': {
                                                        'type': 'Point',
                                                        'coordinates': [-73.93414657, 40.82302903]
                                                    },
                                            # Output field with calculated distance
                                            'distanceField': 'Distance',
                                            # Optional fields
                                            # Spherical geometry
                                            'spherical': True,
                                            # Maximum distance
                                            'maxDistance': 5000,
                                            # Minimum distance
                                            'minDistance': 1000, 
                                            # Quey
                                            'query': {'room_type': 'Private room'},
                                            # Location of the matched document
                                            'includeLocs': 'Location'
                                        }
                        },
                        # Project
                        {
                            '$project':{
                                            '_id':0,
                                            'ID': '$accom_id',
                                            'Distance': 1,
                                            'Location': 1,
                                            'Room': '$room_type'
                                        }
                        },
                        # Limit
                        {
                            '$limit': 5
                       }
                ])

for doc in cur:
    pp.pprint(doc)
# Out:
# {'Distance': 1001.3033274308483,
#  'Location': {'type': 'Point', 'coordinates': [-73.94601, 40.82359]},
#  'ID': 310325,
#  'Room': 'Private room'}
# {'Distance': 1003.4215563304882,
#  'Location': {'type': 'Point', 'coordinates': [-73.94601, 40.82384]},
#  'ID': 24892670,
#  'Room': 'Private room'}
# {'Distance': 1004.2754543256573,
#  'Location': {'type': 'Point', 'coordinates': [-73.94467, 40.81879]},
#  'ID': 31621785,
#  'Room': 'Private room'}
# {'Distance': 1004.8304867337902,
#  'Location': {'type': 'Point', 'coordinates': [-73.946, 40.82404]},
#  'ID': 41840320,
#  'Room': 'Private room'}
# {'Distance': 1005.4592093980679,
#  'Location': {'type': 'Point', 'coordinates': [-73.946, 40.82197]},
#  'ID': 5192165,
#  'Room': 'Private room'}

# %% [markdown]
# ----
# ### Exercises
#
# - Find number of accomodations within 500 meters around `-73.9857, 40.7484` in airbnb collection?
#
# - How many accomodations in airbnb are within the neighbourhoods whose `boro_name` is `Manhattan` and `boro_code` is `1`? ***Use the neighbourhoods collections for this along with the $geoWithin operator.***
#
#
# ----
